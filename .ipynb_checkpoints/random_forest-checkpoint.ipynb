# %%
import pandas as pd
from os import path
from sklearn.ensemble import RandomForestClassifier

# %%
filename = path.join(".", "resources", "exoplanet_data.csv")

df = pd.read_csv(filename)
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
target = df["koi_disposition"]
target_names = ["negative", "positive"]

# %%
data = df.drop("koi_disposition", axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
# Split the data into train/test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=12)

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Train and score the model
rf = RandomForestClassifier(n_estimators=2000) 
rf = rf.fit(X_train, y_train)
rf.score(X_train, y_train)
# Out:
# 1.0

# %%
# Calculate the importance of each feature
importances = rf.feature_importances_
importances
# Out:
# array([0.09559677, 0.06902575, 0.1068114 , 0.03284121, 0.02156534,
#        0.01780726, 0.01710294, 0.01296914, 0.02117273, 0.02204696,
#        0.01828739, 0.01127929, 0.01052174, 0.02243955, 0.03337438,
#        0.0334932 , 0.01969752, 0.01453695, 0.01412191, 0.04924501,
#        0.03183943, 0.03347574, 0.01563427, 0.01612488, 0.01999473,
#        0.01623349, 0.05947967, 0.00320902, 0.0093283 , 0.02821569,
#        0.02799471, 0.00954175, 0.00881294, 0.01050102, 0.00932532,
#        0.01218421, 0.00919689, 0.01234854, 0.01161097, 0.01101198])

# %%
# Sort the features by their importances to use for features selection in other models
sorted(zip(importances, feature_names), reverse=True)
# Out:
# [(0.10681140357424271, 'koi_fpflag_co'),
#  (0.09559676861481055, 'koi_fpflag_nt'),
#  (0.06902574781194852, 'koi_fpflag_ss'),
#  (0.05947967054057045, 'koi_model_snr'),
#  (0.04924500859425178, 'koi_prad'),
#  (0.03349319797074423, 'koi_duration_err2'),
#  (0.03347574320949872, 'koi_prad_err2'),
#  (0.03337437796277381, 'koi_duration_err1'),
#  (0.03284120579701964, 'koi_fpflag_ec'),
#  (0.03183943207889983, 'koi_prad_err1'),
#  (0.02821568660319612, 'koi_steff_err1'),
#  (0.027994712875217202, 'koi_steff_err2'),
#  (0.022439552696582304, 'koi_duration'),
#  (0.02204695826362422, 'koi_time0bk_err2'),
#  (0.021565336630485602, 'koi_period'),
#  (0.02117272633225391, 'koi_time0bk_err1'),
#  (0.019994725606032118, 'koi_insol_err1'),
#  (0.01969752186348921, 'koi_depth'),
#  (0.018287392956581917, 'koi_impact'),
#  (0.01780726405498606, 'koi_period_err1'),
#  (0.01710294169463867, 'koi_period_err2'),
#  (0.01623348938453095, 'koi_insol_err2'),
#  (0.01612487875485574, 'koi_insol'),
#  (0.015634270905042616, 'koi_teq'),
#  (0.014536948800785989, 'koi_depth_err1'),
#  (0.014121911110629666, 'koi_depth_err2'),
#  (0.01296913993187317, 'koi_time0bk'),
#  (0.012348541130749097, 'ra'),
#  (0.012184212199141077, 'koi_srad_err1'),
#  (0.011610973289677069, 'dec'),
#  (0.01127929228182265, 'koi_impact_err1'),
#  (0.011011980768310989, 'koi_kepmag'),
#  (0.010521744870970571, 'koi_impact_err2'),
#  (0.010501019473705105, 'koi_slogg_err2'),
#  (0.009541750901702709, 'koi_slogg'),
#  (0.009328302599559248, 'koi_steff'),
#  (0.00932532021838228, 'koi_srad'),
#  (0.009196887852746275, 'koi_srad_err2'),
#  (0.008812944788419827, 'koi_slogg_err1'),
#  (0.0032090150052473737, 'koi_tce_plnt_num')]
